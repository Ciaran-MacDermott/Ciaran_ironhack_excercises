# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
pd.options.display.max_rows = 100

# %%
file1 = pd.read_csv('Data/file1.csv')
file2 = pd.read_csv('Data/file2.csv')
file3 = pd.read_csv('Data/file3.csv')

# %%
df2=pd.DataFrame(file2)
df3=pd.DataFrame(file3)
df1=pd.DataFrame(file1)

# %%
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
#df = df[['mean', '0', '1', '2', '3']]

#df3=df3[Gender, State, Customer Lifetime Value, Education, Income,Monthly Premium Auto,Number of Open Complaints,Policy Type,Total Claim Amount,Vehicle Class]

cols = list(df3.columns.values)
cols
# Out:
# ['Customer',
#  'State',
#  'Customer Lifetime Value',
#  'Education',
#  'Gender',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Total Claim Amount',
#  'Vehicle Class']

# %%
df3 = df3[[
 'State',
 'Gender',
 'Income',
 'Education',
 'Customer Lifetime Value',
 'Education',
 'Monthly Premium Auto',
 'Number of Open Complaints',
 'Policy Type',
 'Total Claim Amount',
 'Vehicle Class'
]]
df3
# Out:
#            State Gender  Income             Education  \
# 0     Washington      M       0  High School or Below
# 1        Arizona      M       0                Master
# 2         Nevada      F   25820              Bachelor
# 3     California      F       0  High School or Below
# 4     California      M   30366  High School or Below
# ...          ...    ...     ...                   ...
# 7065  California      M   71941              Bachelor
# 7066  California      F   21604               College
# 7067  California      M       0              Bachelor
# 7068  California      M   21941               College
# 7069  California      M       0               College
#
#       Customer Lifetime Value             Education  Monthly Premium Auto  \
# 0                 3479.137523  High School or Below                   104
# 1                 2502.637401                Master                    66
# 2                 3265.156348              Bachelor                    82
# ...

# %%
df3.columns= df3.columns.str.lower()

# %%
#df2
df2.columns= df2.columns.str.lower()

# %%
df2=df2.rename(columns={'st':'state'})

# %%
df2 = df2[[
 'state',
 'gender',
 'income',
 'education',
 'customer lifetime value',
 'education',
 'monthly premium auto',
 'number of open complaints',
 'policy type',
 'total claim amount',
 'vehicle class'
]]
df2
# Out:
#           state gender  income education customer lifetime value education  \
# 0       Arizona      F   16061  Bachelor              323912.47%  Bachelor
# 1    California      F   79487    Master              462680.11%    Master
# 2    California      F   54230   College              899704.02%   College
# 3        Oregon      F   71210   College             2580706.30%   College
# 4       Arizona      F   94903   College              380812.21%   College
# ..          ...    ...     ...       ...                     ...       ...
# 991     Arizona      M   63513    Master              847141.75%    Master
# 992     Arizona      F   58161   College              543121.91%   College
# 993      Nevada      F   83640   College              568964.41%   College
# 994  California      F       0    Master              368672.38%    Master
# 995  California      M       0  Bachelor              399258.39%  Bachelor
#
# ...

# %%
df1=pd.DataFrame(file1)
df1.columns= df1.columns.str.lower()
df1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df1=df1.rename(columns={'st':'state'})

# %%
df1 = df1[[
 'state',
 'gender',
 'income',
 'education',
 'customer lifetime value',
 'education',
 'monthly premium auto',
 'number of open complaints',
 'policy type',
 'total claim amount',
 'vehicle class'
]]
df1
# Out:
#            state gender   income             education  \
# 0     Washington    NaN      0.0                Master
# 1        Arizona      F      0.0              Bachelor
# 2         Nevada      F  48767.0              Bachelor
# 3     California      M      0.0              Bachelor
# 4     Washington      M  36357.0  High School or Below
# ...          ...    ...      ...                   ...
# 4003         NaN    NaN      NaN                   NaN
# 4004         NaN    NaN      NaN                   NaN
# 4005         NaN    NaN      NaN                   NaN
# 4006         NaN    NaN      NaN                   NaN
# 4007         NaN    NaN      NaN                   NaN
#
#      customer lifetime value             education  monthly premium auto  \
# 0                        NaN                Master                1000.0
# 1                 697953.59%              Bachelor                  94.0
# 2                1288743.17%              Bachelor                 108.0
# ...

# %%
main_df=pd.concat([df1, df2, df3], axis=0)

main_df
# Out:
#            state gender   income             education  \
# 0     Washington    NaN      0.0                Master
# 1        Arizona      F      0.0              Bachelor
# 2         Nevada      F  48767.0              Bachelor
# 3     California      M      0.0              Bachelor
# 4     Washington      M  36357.0  High School or Below
# ...          ...    ...      ...                   ...
# 7065  California      M  71941.0              Bachelor
# 7066  California      F  21604.0               College
# 7067  California      M      0.0              Bachelor
# 7068  California      M  21941.0               College
# 7069  California      M      0.0               College
#
#      customer lifetime value             education  monthly premium auto  \
# 0                        NaN                Master                1000.0
# 1                 697953.59%              Bachelor                  94.0
# 2                1288743.17%              Bachelor                 108.0
# ...

# %%
perc = 100.0 
min_count =  int(((100-perc)/100)*df.shape[1] + 1)
main_df = main_df.dropna( axis=0, 
                    thresh=min_count)

print("Modified Dataframe : ")
main_df
# Out:
# Modified Dataframe :
#            state gender   income             education  \
# 0     Washington    NaN      0.0                Master
# 1        Arizona      F      0.0              Bachelor
# 2         Nevada      F  48767.0              Bachelor
# 3     California      M      0.0              Bachelor
# 4     Washington      M  36357.0  High School or Below
# ...          ...    ...      ...                   ...
# 7065  California      M  71941.0              Bachelor
# 7066  California      F  21604.0               College
# 7067  California      M      0.0              Bachelor
# 7068  California      M  21941.0               College
# 7069  California      M      0.0               College
#
#      customer lifetime value             education  monthly premium auto  \
# 0                        NaN                Master                1000.0
# 1                 697953.59%              Bachelor                  94.0
# ...

# %%
main_df.isna().sum()/len(main_df)
# Out:
# state                        0.000000
# gender                       0.013352
# income                       0.000000
# education                    0.000000
# customer lifetime value      0.000766
# education                    0.000000
# monthly premium auto         0.000000
# number of open complaints    0.000000
# policy type                  0.000000
# total claim amount           0.000000
# vehicle class                0.000000
# dtype: float64

# %%
main_df.shape
# Out:
# (9137, 11)

# %%
main_df.drop_duplicates()
# Out:
#            state gender   income             education  \
# 0     Washington    NaN      0.0                Master
# 1        Arizona      F      0.0              Bachelor
# 2         Nevada      F  48767.0              Bachelor
# 3     California      M      0.0              Bachelor
# 4     Washington      M  36357.0  High School or Below
# ...          ...    ...      ...                   ...
# 7065  California      M  71941.0              Bachelor
# 7066  California      F  21604.0               College
# 7067  California      M      0.0              Bachelor
# 7068  California      M  21941.0               College
# 7069  California      M      0.0               College
#
#      customer lifetime value             education  monthly premium auto  \
# 0                        NaN                Master                1000.0
# 1                 697953.59%              Bachelor                  94.0
# 2                1288743.17%              Bachelor                 108.0
# ...

# %%
#main_df['customer lifetime value'] = main_df['customer lifetime value'].map(lambda x: x.lstrip('%').rstrip(' '))

#main_df['customer lifetime value'] = main_df['customer lifetime value'].astype("float")



#main_df['customer lifetime value'] = main_df['customer lifetime value'].replace(r"%","", regex=True)

#main_df['customer lifetime value'] = main_df['customer lifetime value'].astype("float")

# %%
main_df = main_df[main_df['customer lifetime value'].isna()==False]
                          
main_df
# Out:
#            state gender   income             education  \
# 1        Arizona      F      0.0              Bachelor
# 2         Nevada      F  48767.0              Bachelor
# 3     California      M      0.0              Bachelor
# 4     Washington      M  36357.0  High School or Below
# 5         Oregon      F  62902.0              Bachelor
# ...          ...    ...      ...                   ...
# 7065  California      M  71941.0              Bachelor
# 7066  California      F  21604.0               College
# 7067  California      M      0.0              Bachelor
# 7068  California      M  21941.0               College
# 7069  California      M      0.0               College
#
#      customer lifetime value             education  monthly premium auto  \
# 1                 697953.59%              Bachelor                  94.0
# 2                1288743.17%              Bachelor                 108.0
# 3                 764586.18%              Bachelor                 106.0
# ...

# %%
main_df
# Out:
#            state gender   income             education  \
# 1        Arizona      F      0.0              Bachelor
# 2         Nevada      F  48767.0              Bachelor
# 3     California      M      0.0              Bachelor
# 4     Washington      M  36357.0  High School or Below
# 5         Oregon      F  62902.0              Bachelor
# ...          ...    ...      ...                   ...
# 7065  California      M  71941.0              Bachelor
# 7066  California      F  21604.0               College
# 7067  California      M      0.0              Bachelor
# 7068  California      M  21941.0               College
# 7069  California      M      0.0               College
#
#      customer lifetime value             education  monthly premium auto  \
# 1                 697953.59%              Bachelor                  94.0
# 2                1288743.17%              Bachelor                 108.0
# 3                 764586.18%              Bachelor                 106.0
# ...

# %%
#main_df['customer lifetime value'] = main_df['customer lifetime value'].astype(int)


main_df['customer lifetime value'] = main_df['customer lifetime value'].replace(r"%","", regex=True)
main_df
# Out:
# /var/folders/p_/wx7lhsds7k55bv_lwkld0fkr0000gn/T/ipykernel_16870/48491140.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_df['customer lifetime value'] = main_df['customer lifetime value'].replace(r"%","", regex=True)
#            state gender   income             education  \
# 1        Arizona      F      0.0              Bachelor
# 2         Nevada      F  48767.0              Bachelor
# 3     California      M      0.0              Bachelor
# 4     Washington      M  36357.0  High School or Below
# 5         Oregon      F  62902.0              Bachelor
# ...          ...    ...      ...                   ...
# 7065  California      M  71941.0              Bachelor
# 7066  California      F  21604.0               College
# ...

# %%
main_df['customer lifetime value'] = main_df['customer lifetime value'].round()

main_df['customer lifetime value'] = main_df['customer lifetime value'].astype(int)

main_df
# Out:
# /var/folders/p_/wx7lhsds7k55bv_lwkld0fkr0000gn/T/ipykernel_16870/1193240780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_df['customer lifetime value'] = main_df['customer lifetime value'].round()
# /var/folders/p_/wx7lhsds7k55bv_lwkld0fkr0000gn/T/ipykernel_16870/1193240780.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_df['customer lifetime value'] = main_df['customer lifetime value'].astype(int)
#            state gender   income             education  \
# ...
