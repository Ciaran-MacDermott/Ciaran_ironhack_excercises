# %% [markdown]
# ![Sicily%20Italy%20landscape%20with%20water%20and%20homes%20in%20background.jpeg](attachment:Sicily%20Italy%20landscape%20with%20water%20and%20homes%20in%20background.jpeg)

# %% [markdown]
# [Sicily Video Excercise](https://www.youtube.com/watch?v=anjq43EhoP8)

# %% [markdown]
# This Notebook is designed to teach us how to use Markdown

# %% [markdown]
# Thomas loves going on holiday to Sicily and goes there every October.

# %% [markdown]
# * They love eating ice cream
# * Going to the beach
# *Hiking up volcanoes

# %% [markdown]
# # Sicily

# %% [markdown]
# **He loves riding on his moped**

# %% [markdown]
# *and always wears his helmet*

# %%
Thomas = 20
Thomas + 7
#this is a simple addition formula with thomas representing 20
# Out:
# 27

# %%
from IPython.display import Audio,Image, YouTubeVideo
id='https://youtu.be/Izu2Ny6kwxI'
YouTubeVideo(id=id,width=600,height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://www.youtube.com/embed/https://youtu.be/Izu2Ny6kwxI"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
